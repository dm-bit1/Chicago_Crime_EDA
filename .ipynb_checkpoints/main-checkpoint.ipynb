# %% [markdown]
# Tasks to do:
# 1. Implement a plot for ages of sex offenders in bins, e.g. 20-30, 30-40, etc.
# 2. Make a plot for sex offenses by gender.
# 3. What dates are in the dataset? Unfortunately, it does not tell us the dates of the crimes.
# 4. Make a box-and-wisker plot for ages of sex offenders.
# 5. Calculate descriptive stats. E.g. Median age of sex offenders. Mean, median, mode, variance, standard deviation, and range.
# 6. Make a bivariate analysis. E.g. Gender with the block and number of offenders.
# 7. Write a summary at the top that describes the plots and statistics for sex offender data. Then, do the same for the crime data.

# %% [markdown]
# Summary
#
# This notebook does exploratory data analysis (ERD) on Chicago's crime databases. There are two main data sources: 1. City of Chicago's Crime Database which is a qualitive dataset. 2. The Chicago Sex Offender Database which is a qualitative dataset.

# %% [markdown]
# This database shows the City of Chicago's database of sex offenders. It uses the Socrata 2.0 API with endpoint shown here(JSON) "https://data.cityofchicago.org/resource/vc9r-bqvy.json".
#
# This database shows the City of Chicago's overall crime database with API endpoint "https://data.cityofchicago.org/resource/x2n5-8w5q.json".

# %% [markdown]
# The cell below uses the API endpoint to get data for Chicago crimes. The object returned is a list type.

# %%
import requests

response_1 = requests.get("https://data.cityofchicago.org/resource/vc9r-bqvy.json?$limit=50000&$offset=0")

# This dataset has the sex offender's data.
crime_data_1 = response_1.json()

# %%
import sys
sys.executable
# Out:
# 'D:\\Anaconda\\envs\\test\\python.exe'

# %%
# print the first 100 rows for inspection
for i in range(0, 100):
    print(crime_data_1[i])

print(len(crime_data_1))
# Out:
# {'last': 'VALLEJO', 'first': 'MAURICE', 'block': '0000X  0', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '06/19/1970', 'height': '509', 'weight': '170', 'victim_minor': 'Y'}
# {'last': 'BALENTINE', 'first': 'RUFUS', 'block': '0000X  165TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '03/10/1958', 'height': '603', 'weight': '300', 'victim_minor': 'Y'}
# {'last': 'DROZD', 'first': 'ERIC', 'block': '0000X  28W012 GALUSHA', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '06/16/1984', 'height': '511', 'weight': '145', 'victim_minor': 'N'}
# {'last': 'FREEMAN', 'first': 'GARY', 'block': '0000X  ANNABLE COURT', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '02/19/1965', 'height': '511', 'weight': '200', 'victim_minor': 'Y'}
# {'last': 'BELL', 'first': 'ARMOUR', 'block': '0000X  ANNABLE CT', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '10/11/1935', 'height': '601', 'weight': '152', 'victim_minor': 'Y'}
# {'last': 'WINKOWITISCH', 'first': 'CHAD', 'block': '0000X  BRUCE LANE', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '06/10/1974', 'height': '602', 'weight': '170', 'victim_minor': 'Y'}
# {'last': 'MINEV', 'first': 'VESSELIN', 'block': '0000X  BUL', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '10/05/1970', 'height': '510', 'weight': '165', 'victim_minor': 'N'}
# {'last': 'QUINONES', 'first': 'GILBERTO', 'block': '0000X  CALLE LLINAS', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '01/13/1956', 'height': '509', 'weight': '170', 'victim_minor': 'Y'}
# {'last': 'VINES', 'first': 'JEFFREY', 'block': '0000X  CARRER GIRONA 25', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '07/24/1948', 'height': '510', 'weight': '170', 'victim_minor': 'Y'}
# {'last': 'CLARK', 'first': 'MARVIN', 'block': '0000X  DAWN LN', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '01/27/1993', 'height': '602', 'weight': '236', 'victim_minor': 'Y'}
# {'last': 'WILLIAMS', 'first': 'RANDALL', 'block': '0000X  DEPARTMENT OF HUMAN SERVICE', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '07/21/1960', 'height': '511', 'weight': '253', 'victim_minor': 'N'}
# {'last': 'PEREZ', 'first': 'NELSON', 'block': '0000X  DEPORTED', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '04/22/1979', 'height': '509', 'weight': '190', 'victim_minor': 'Y'}
# {'last': 'PEREZ', 'first': 'ALFREDO', 'block': '0000X  DEPORTED TO ECUADOR', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '09/18/1975', 'height': '501', 'weight': '160', 'victim_minor': 'Y'}
# {'last': 'RIDGEWAY', 'first': 'CHARLES', 'block': '0000X  DONHU COURT', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '05/15/1966', 'height': '507', 'weight': '180', 'victim_minor': 'Y'}
# {'last': 'WHITE', 'first': 'CHARLES', 'block': '0000X E 100TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '05/02/1961', 'height': '510', 'weight': '185', 'victim_minor': 'Y'}
# {'last': 'GANT', 'first': 'DWIGHT', 'block': '0000X E 104TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '02/03/1962', 'height': '510', 'weight': '243', 'victim_minor': 'Y'}
# {'last': 'WILLIAMS', 'first': 'TORRANCE', 'block': '0000X E 110TH PL', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '01/14/1974', 'height': '511', 'weight': '220', 'victim_minor': 'Y'}
# {'last': 'HASKINS', 'first': 'JOHNNY', 'block': '0000X E 111TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '05/23/1969', 'height': '510', 'weight': '140', 'victim_minor': 'N'}
# {'last': 'WILLIS', 'first': 'KEITH', 'block': '0000X E 120TH PL', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '08/23/1955', 'height': '510', 'weight': '165', 'victim_minor': 'Y'}
# {'last': 'MAYES', 'first': 'NIGLE', 'block': '0000X E 36TH PL', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '06/14/1977', 'height': '507', 'weight': '180', 'victim_minor': 'Y'}
# {'last': 'BARBER', 'first': 'ROBERT', 'block': '0000X E 7TH STREET', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '08/28/1974', 'height': '511', 'weight': '290', 'victim_minor': 'Y'}
# {'last': 'JORDAN', 'first': 'CHRISTOPHER', 'block': '0000X E BRAYTON ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '12/18/1968', 'height': '507', 'weight': '178', 'victim_minor': 'N'}
# {'last': 'SPECTOR', 'first': 'ARI', 'block': '0000X E STATE PARKWAY', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '07/23/1965', 'height': '507', 'weight': '150', 'victim_minor': 'Y'}
# {'last': 'ZANT', 'first': 'JOSEPH', 'block': '0000X  FORSYTHIA', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '07/03/1985', 'height': '510', 'weight': '195', 'victim_minor': 'N'}
# {'last': 'RIZVI', 'first': 'MOHAMMAD', 'block': '0000X  GULSHAN E IQBAL', 'gender': 'MALE', 'race': 'UNKNOWN / REFUSED', 'birth_date': '01/10/1960', 'height': '506', 'weight': '120', 'victim_minor': 'Y'}
# {'last': 'FAVELA', 'first': 'DANIEL', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '01/06/1987', 'height': '509', 'weight': '197', 'victim_minor': 'N'}
# {'last': 'FERRALEZ', 'first': 'BRANDON', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '02/12/1981', 'height': '507', 'weight': '230', 'victim_minor': 'N'}
# {'last': 'HAYES', 'first': 'DENZEL', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '11/13/1992', 'height': '510', 'weight': '315', 'victim_minor': 'Y'}
# {'last': 'JARRETT', 'first': 'ANDRE', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '07/02/1974', 'height': '506', 'weight': '230', 'victim_minor': 'Y'}
# {'last': 'LAFOND', 'first': 'JAMES', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '08/28/1959', 'height': '506', 'weight': '150', 'victim_minor': 'N'}
# {'last': 'LEWIS', 'first': 'EIAN', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '08/14/1980', 'height': '600', 'weight': '195', 'victim_minor': 'Y'}
# {'last': 'MOORE', 'first': 'ALLEN', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '01/30/1957', 'height': '511', 'weight': '220', 'victim_minor': 'Y'}
# {'last': 'RIVERA', 'first': 'RICHARD', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '07/29/1973', 'height': '509', 'weight': '180', 'victim_minor': 'Y'}
# {'last': 'SHOTLOW', 'first': 'FREDERICK', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '03/25/1971', 'height': '510', 'weight': '175', 'victim_minor': 'Y'}
# {'last': 'SPACE', 'first': 'RUDY', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '06/22/1981', 'height': '510', 'weight': '185', 'victim_minor': 'Y'}
# {'last': 'TABOR', 'first': 'BRUCE', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '04/16/1962', 'height': '507', 'weight': '180', 'victim_minor': 'Y'}
# {'last': 'TORRES', 'first': 'WILHELM', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '07/20/1992', 'height': '602', 'weight': '190', 'victim_minor': 'Y'}
# {'last': 'WLECKE', 'first': 'DANIEL', 'block': '0000X  HOMELESS', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '03/20/1950', 'height': '510', 'weight': '195', 'victim_minor': 'N'}
# {'last': 'TREJO', 'first': 'ESMERALDA', 'block': '0000X  JUAREZ #1', 'gender': 'FEMALE', 'race': 'WHITE HISPANIC', 'birth_date': '02/06/1998', 'height': '508', 'weight': '217', 'victim_minor': 'N'}
# {'last': 'CHISUM', 'first': 'SHERDALE', 'block': '0000X  LANCE DR', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '07/03/1962', 'height': '601', 'weight': '170', 'victim_minor': 'Y'}
# {'last': 'CONLEY', 'first': 'DEMETRIUS', 'block': '0000X  MACON LANE ROAD', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '01/07/1989', 'height': '506', 'weight': '156', 'victim_minor': 'Y'}
# {'last': 'REED', 'first': 'JEFFREY', 'block': '0000X  MIDLAND DR', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '08/26/1981', 'height': '602', 'weight': '185', 'victim_minor': 'Y'}
# {'last': 'LOTT', 'first': 'BOBBIE', 'block': '0000X  MOSS WAY', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '11/05/1976', 'height': '507', 'weight': '157', 'victim_minor': 'Y'}
# {'last': 'RODGERS', 'first': 'MATTHEW', 'block': '0000X N 48TH  ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '10/05/1964', 'height': '507', 'weight': '185', 'victim_minor': 'Y'}
# {'last': 'LINDSEY', 'first': 'KORY', 'block': '0000X N CRYSTAL AVE', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '11/19/1994', 'height': '511', 'weight': '150', 'victim_minor': 'Y'}
# {'last': 'MARTINEZ', 'first': 'JASON', 'block': '0000X  NICHOLS AVE', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '02/26/1977', 'height': '602', 'weight': '210', 'victim_minor': 'N'}
# {'last': 'GUNN', 'first': 'RAPHAEL', 'block': '0000X N LONG AVE', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '08/01/1977', 'height': '509', 'weight': '185', 'victim_minor': 'Y'}
# {'last': 'REDMOND', 'first': 'KEONMARTEL', 'block': '0000X N LOREL AVE', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '06/12/1987', 'height': '509', 'weight': '200', 'victim_minor': 'Y'}
# {'last': 'COVINGTON', 'first': 'MICHAEL', 'block': '0000X N MENARD AVE', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '08/13/1955', 'height': '601', 'weight': '245', 'victim_minor': 'N'}
# {'last': 'PARRA', 'first': 'JESUS', 'block': '0000X  NORTE 2GN58', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '01/11/1938', 'height': '509', 'weight': '150', 'victim_minor': 'Y'}
# {'last': 'CLARK', 'first': 'TYRICE', 'block': '0000X N PINE AVE', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '03/13/1993', 'height': '511', 'weight': '250', 'victim_minor': 'Y'}
# {'last': 'QUIROZ', 'first': 'JOSE', 'block': '0000X N STATE ST', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '11/14/1983', 'height': '508', 'weight': '175', 'victim_minor': 'Y'}
# {'last': 'REED', 'first': 'REGINALD', 'block': '0000X N WALLER AVE', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '11/14/1967', 'height': '502', 'weight': '215', 'victim_minor': 'N'}
# {'last': 'WEATHERSPOON', 'first': 'LEON', 'block': '0000X  OAK CT', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '08/25/1983', 'height': '504', 'weight': '160', 'victim_minor': 'Y'}
# {'last': 'LUKAC', 'first': 'RADE', 'block': '0000X  OMLADINSKIH RADNIH BRIGADA', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '02/19/1972', 'height': '509', 'weight': '180', 'victim_minor': 'Y'}
# {'last': 'MILLER', 'first': 'WILLIAM', 'block': '0000X  ORCHARD PARK RD', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '09/03/1988', 'height': '508', 'weight': '176', 'victim_minor': 'Y'}
# {'last': 'MONTGOMERY', 'first': 'MANSEL', 'block': '0000X  RAINDROP COVE', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '07/21/1970', 'height': '607', 'weight': '250', 'victim_minor': 'N'}
# {'last': 'WALKER', 'first': 'JOHNNY', 'block': '0000X S 157TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '08/01/1976', 'height': '506', 'weight': '200', 'victim_minor': 'Y'}
# {'last': 'GARCIA', 'first': 'JOHN', 'block': '0000X S 360 MADISON ST', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '04/24/1969', 'height': '600', 'weight': '248', 'victim_minor': 'Y'}
# {'last': 'DANIEL', 'first': 'ERNEST', 'block': '0000X S 670 RT 59', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '09/30/1965', 'height': '601', 'weight': '237', 'victim_minor': 'Y'}
# {'last': 'OVIEDO', 'first': 'SAMUEL', 'block': '0000X  SEXTANT DR', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '08/20/1974', 'height': '503', 'weight': '175', 'victim_minor': 'Y'}
# {'last': 'WILSON', 'first': 'ANDRE', 'block': '0000X S KOSTNER AVE', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '10/15/1988', 'height': '602', 'weight': '210', 'victim_minor': 'N'}
# {'last': 'MORTON', 'first': 'ERIC', 'block': '0000X S LEAMINGTON AVE', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '01/30/1973', 'height': '603', 'weight': '220', 'victim_minor': 'Y'}
# {'last': 'PITTMAN', 'first': 'LAWRENCE', 'block': '0000X S MLK JR AV', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '01/08/1955', 'height': '507', 'weight': '140', 'victim_minor': 'Y'}
# {'last': 'PAWLICKI', 'first': 'STEPHEN', 'block': '0000X S MLK JR AVE', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '05/16/1972', 'height': '506', 'weight': '170', 'victim_minor': 'Y'}
# {'last': 'SIDDIQI', 'first': 'JAWWAD', 'block': '0000X  STATE PKW', 'gender': 'MALE', 'race': 'UNKNOWN / REFUSED', 'birth_date': '01/21/1964', 'height': '510', 'weight': '160', 'victim_minor': 'Y'}
# {'last': 'COLE', 'first': 'LEON', 'block': '0000X  STEPP LINE RD', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '10/01/1969', 'height': '602', 'weight': '275', 'victim_minor': 'Y'}
# {'last': 'MITCHELL', 'first': 'LAWRENCE', 'block': '0000X W 104TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '12/09/1945', 'height': '511', 'weight': '162', 'victim_minor': 'Y'}
# {'last': 'RAMSEY', 'first': 'CHARLES', 'block': '0000X W 107TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '08/22/1970', 'height': '505', 'weight': '178', 'victim_minor': 'Y'}
# {'last': 'DAVIS', 'first': 'IZEAR', 'block': '0000X W 108TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '10/21/1972', 'height': '507', 'weight': '215', 'victim_minor': 'Y'}
# {'last': 'HERRERA', 'first': 'MATTHEW', 'block': '0000X W 108TH ST', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '07/04/1965', 'height': '504', 'weight': '185', 'victim_minor': 'Y'}
# {'last': 'BOLDEN', 'first': 'TERRY', 'block': '0000X W 111TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '04/18/1957', 'height': '509', 'weight': '170', 'victim_minor': 'Y'}
# {'last': 'WADE', 'first': 'DESMOND', 'block': '0000X W 111TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '05/19/1971', 'height': '511', 'weight': '227', 'victim_minor': 'Y'}
# {'last': 'FRICKSON', 'first': 'DENNIS', 'block': '0000X W 112TH PL', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '11/17/1948', 'height': '603', 'weight': '185', 'victim_minor': 'Y'}
# {'last': 'INGRAM', 'first': 'CLYNN', 'block': '0000X W 112TH PL', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '10/02/1962', 'height': '511', 'weight': '180', 'victim_minor': 'Y'}
# {'last': 'ELMORE', 'first': 'MARCUS', 'block': '0000X W 112TH ST', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '02/20/1986', 'height': '600', 'weight': '190', 'victim_minor': 'Y'}
# {'last': 'MOORE', 'first': 'WALTER', 'block': '0000X W 112TH ST', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '05/10/1966', 'height': '507', 'weight': '206', 'victim_minor': 'Y'}
# {'last': 'KAHILL', 'first': 'ARTHUR', 'block': '0000X W 113TH PL', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '11/03/1973', 'height': '601', 'weight': '280', 'victim_minor': 'Y'}
# {'last': 'JOHNSON', 'first': 'ANTHONY', 'block': '0000X W 15TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '08/13/1964', 'height': '509', 'weight': '215', 'victim_minor': 'N'}
# {'last': 'WELSH', 'first': 'GARY', 'block': '0000X W 204 ALLEN RD', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '05/24/1939', 'height': '505', 'weight': '175', 'victim_minor': 'Y'}
# {'last': 'WILLIAMS', 'first': 'ANTONIO', 'block': '0000X W  545 ROOSEVELT RD', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '02/18/1978', 'height': '511', 'weight': '189', 'victim_minor': 'Y'}
# {'last': 'ROSIN', 'first': 'MITCHELL', 'block': '0000X W 70TH ST', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '11/11/1966', 'height': '511', 'weight': '190', 'victim_minor': 'Y'}
# {'last': 'SANSON', 'first': 'MICHAEL', 'block': '0000X W 83RD ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '06/17/1962', 'height': '502', 'weight': '145', 'victim_minor': 'Y'}
# {'last': 'AUSTIN', 'first': 'ARTERIA', 'block': '0000X W DONOVAN CT', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '11/18/1990', 'height': '507', 'weight': '165', 'victim_minor': 'N'}
# {'last': 'LOTT', 'first': 'SHANE', 'block': '0000X W PACIFIC AVE', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '01/07/1986', 'height': '601', 'weight': '182', 'victim_minor': 'Y'}
# {'last': 'UPCHURCH', 'first': 'ANTHONY', 'block': '001XX  1ST ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '12/18/1969', 'height': '506', 'weight': '172', 'victim_minor': 'N'}
# {'last': 'BOONE', 'first': 'MICHAEL', 'block': '001XX  BLACKHAWK DR', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '09/13/1957', 'height': '600', 'weight': '230', 'victim_minor': 'N'}
# {'last': 'MCKENNA', 'first': 'MICHAEL', 'block': '001XX  BLUFF VIEW DR', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '12/14/1959', 'height': '605', 'weight': '210', 'victim_minor': 'Y'}
# {'last': 'ROSADO', 'first': 'GEORGE', 'block': '001XX  COMBS ST', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '04/06/1987', 'height': '505', 'weight': '140', 'victim_minor': 'Y'}
# {'last': 'SMITH', 'first': 'CLINTON', 'block': '001XX E 103RD ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '09/11/1957', 'height': '509', 'weight': '180', 'victim_minor': 'N'}
# {'last': 'RAHN', 'first': 'DENNIS', 'block': '001XX E 111TH ST', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '05/04/1981', 'height': '600', 'weight': '175', 'victim_minor': 'Y'}
# {'last': 'RICHARDSON', 'first': 'JEFFREY', 'block': '001XX E 111TH ST', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '10/21/1978', 'height': '600', 'weight': '197', 'victim_minor': 'Y'}
# {'last': 'SNIDER', 'first': 'DEREK', 'block': '001XX E 111TH ST', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '06/09/1990', 'height': '511', 'weight': '248', 'victim_minor': 'Y'}
# {'last': 'SPIKER', 'first': 'JEFFERY', 'block': '001XX E 111TH ST', 'gender': 'MALE', 'race': 'WHITE', 'birth_date': '07/17/1972', 'height': '507', 'weight': '150', 'victim_minor': 'Y'}
# {'last': 'HOWARD', 'first': 'LYNELL', 'block': '001XX E 119TH PL', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '03/18/1961', 'height': '505', 'weight': '140', 'victim_minor': 'Y'}
# {'last': 'GARCIA', 'first': 'BERNARDO', 'block': '001XX E 120TH PL', 'gender': 'MALE', 'race': 'WHITE HISPANIC', 'birth_date': '08/19/1971', 'height': '508', 'weight': '160', 'victim_minor': 'Y'}
# {'last': 'GREER', 'first': 'ANTONIO', 'block': '001XX E 120TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '06/14/1964', 'height': '508', 'weight': '160', 'victim_minor': 'N'}
# {'last': 'JOHNSON', 'first': 'ERIC', 'block': '001XX E 14TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '10/19/1971', 'height': '604', 'weight': '195', 'victim_minor': 'Y'}
# {'last': 'ALLEN', 'first': 'DONALD', 'block': '001XX E 155TH ST', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '05/15/1943', 'height': '507', 'weight': '190', 'victim_minor': 'N'}
# {'last': 'BUTLER', 'first': 'CHRIS', 'block': '001XX E JOHN', 'gender': 'MALE', 'race': 'BLACK', 'birth_date': '04/17/1981', 'height': '507', 'weight': '175', 'victim_minor': 'Y'}
# 3698

# %%
import pandas as pd

df = pd.DataFrame(crime_data_1) # Convert crime data from a list to a DataFrame.

df.head(10)

df = df.sort_values(by = df.columns[1]) # Sort the values by first.

df.head(10)
# Out:
#            last  first                          block gender            race  \
# 3083     FOSTER  AARIN       15XXX S ROSE RIDGE COURT   MALE           BLACK
# 780     COLEMAN  AARON                015XX E 73RD PL   MALE           BLACK
# 2654  ZIELINSKI  AARON          087XX S BALTIMORE AVE   MALE           WHITE
# 1893      ONEAL  AARON               057XX S GREEN ST   MALE           BLACK
# 146    BLACKHAM  AARON           002XX  MASONIC DRIVE   MALE           WHITE
# 1380      JONES  AARON           038XX W FERDINAND ST   MALE           WHITE
# 3550     ROGERS  AARON       (registered as homeless)   MALE           BLACK
# 1299       CRUZ  AARON              034XX S MORGAN ST   MALE  WHITE HISPANIC
# 1239    AGUILAR  AARON  030XX  SUMMERFIELD RIDGE LANE   MALE  WHITE HISPANIC
# 1978     WALKER  AARON            060XX S NORMAL BLVD   MALE           BLACK
#
#       birth_date height weight victim_minor
# 3083  04/02/1975    600    195            Y
# 780   03/31/1961    511    170            Y
# 2654  01/18/1993    600    190            Y
# 1893  10/04/1965    601    193            N
# 146   05/15/1970    510    185            Y
# 1380  05/28/1990    600    181            Y
# 3550  01/02/2000    504    109            Y
# 1299  07/06/1999    505    280            N
# 1239  05/12/1984    600    240            Y
# 1978  12/26/1967    507    150            Y

# %%
# Clean the data by checking for columns with null values.
print(type(crime_data_1))

print(type(crime_data_1[0]))

# Find the percentage of null or missing values
null_percent = round(100 * (df.isnull().sum() / len(df.index)), 2)

# Print the columns which have more than 0% missing values.
null_percent[null_percent > 0]

null_indices = df['block'].isnull()

print(df[null_indices].head(10))
# Out:
# <class 'list'>
# <class 'dict'>
#          last    first block gender            race  birth_date height weight  \
# 3668      COE    ALVIN   NaN   MALE           BLACK  05/04/1979    603    197
# 3691    SMITH    BOBBY   NaN   MALE           BLACK  01/30/1960    600    480
# 3669  COLLIER   CALVIN   NaN   MALE           BLACK  02/22/1961    506    151
# 3690  SANCHEZ   CARLOS   NaN   MALE  WHITE HISPANIC  08/28/1972    510    180
# 3672   FARRIS  CEDRICK   NaN   MALE           BLACK  04/18/1968    506    169
# 3681   MILLER     DALE   NaN   MALE           BLACK  03/27/1953    507    162
# 3682   MURPHY    DANTE   NaN   MALE           BLACK  10/24/1991    510    140
# 3694    TRULL   DWAYNE   NaN   MALE           BLACK  02/07/1961    508    165
# 3680    MATOS    EDWIN   NaN   MALE  WHITE HISPANIC  06/29/1965    507    145
# 3677  JIMENEZ   EFRAIN   NaN   MALE  WHITE HISPANIC  05/25/1946    505    140
#
#      victim_minor
# 3668            N
# 3691            Y
# 3669            Y
# 3690            Y
# 3672            Y
# 3681            N
# 3682            Y
# 3694            N
# 3680            Y
# 3677            Y

# %% [markdown]
# The print statement above shows that block is the only column with missing values at 0.76% missing or NaN. This column will be cleaned by way of imputation. That is, I shall make the missing block values contain unknown.

# %%
# In the block column, replace all NaN with unknown.
df['block'].fillna('unknown', inplace=True)

rows = df[df['block'] == 'unknown']

rows.head(10)
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_12944\1875386691.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['block'].fillna('unknown', inplace=True)
#          last    first    block gender            race  birth_date height  \
# 3668      COE    ALVIN  unknown   MALE           BLACK  05/04/1979    603
# 3691    SMITH    BOBBY  unknown   MALE           BLACK  01/30/1960    600
# 3669  COLLIER   CALVIN  unknown   MALE           BLACK  02/22/1961    506
# 3690  SANCHEZ   CARLOS  unknown   MALE  WHITE HISPANIC  08/28/1972    510
# 3672   FARRIS  CEDRICK  unknown   MALE           BLACK  04/18/1968    506
# 3681   MILLER     DALE  unknown   MALE           BLACK  03/27/1953    507
# 3682   MURPHY    DANTE  unknown   MALE           BLACK  10/24/1991    510
# 3694    TRULL   DWAYNE  unknown   MALE           BLACK  02/07/1961    508
# 3680    MATOS    EDWIN  unknown   MALE  WHITE HISPANIC  06/29/1965    507
# 3677  JIMENEZ   EFRAIN  unknown   MALE  WHITE HISPANIC  05/25/1946    505
#
#      weight victim_minor
# 3668    197            N
# 3691    480            Y
# 3669    151            Y
# 3690    180            Y
# 3672    169            Y
# 3681    162            N
# 3682    140            Y
# 3694    165            N
# 3680    145            Y
# 3677    140            Y

# %%
# What comumns are present in the data?
df.columns
# Out:
# Index(['last', 'first', 'block', 'gender', 'race', 'birth_date', 'height',
#        'weight', 'victim_minor'],
#       dtype='object')

# %%
print( df['first'].dtype )# verify its a string type

countFirst = df['first'].value_counts() # counts instances of each first name

print(countFirst.head(20)) # prints the first 20 values for first names DF

countRace = df['race'].value_counts() # counts instances of each race

print(countRace.head(20))

countLast = df['last'].value_counts() # counts instances of each last name

print(countLast.head(20))

countHeight = df['height'].value_counts()

print(countHeight)

countMinor = df['victim_minor'].value_counts()

print(countMinor)

countBlock = df['block'].value_counts()

print(countBlock)
# Out:
# object
# first
# MICHAEL        114
# JAMES           74
# ROBERT          67
# DAVID           66
# ANTHONY         55
# JOHN            51
# JOSE            48
# WILLIAM         43
# JOSEPH          39
# CHRISTOPHER     39
# CHARLES         38
# RICHARD         34
# ERIC            32
# ANTONIO         29
# KEVIN           29
# KENNETH         28
# LARRY           28
# LUIS            28
# JUAN            26
# THOMAS          26
# Name: count, dtype: int64
# race
# BLACK                           2084
# WHITE                            854
# WHITE HISPANIC                   692
# ASIAN / PACIFIC ISLANDER          35
# BLACK HISPANIC                    20
# UNKNOWN / REFUSED                 10
# AMER INDIAN / ALASKAN NATIVE       3
# Name: count, dtype: int64
# last
# WILLIAMS     59
# JOHNSON      41
# JONES        36
# JACKSON      35
# SMITH        31
# DAVIS        30
# RODRIGUEZ    29
# THOMAS       25
# GARCIA       24
# BROWN        22
# HARRIS       21
# MOORE        20
# ROBINSON     17
# MARTINEZ     17
# LOPEZ        17
# ANDERSON     16
# LEWIS        16
# WHITE        15
# ALLEN        14
# THOMPSON     14
# Name: count, dtype: int64
# height
# 509    440
# 507    406
# 511    403
# 510    380
# 600    356
# 508    336
# 506    302
# 601    262
# 602    210
# 505    169
# 603    108
# 504     95
# 503     64
# 604     50
# 502     37
# 605     23
# 501     13
# 606     11
# 500     11
# 411      5
# 607      3
# 608      2
# 609      2
# 60       1
# 294      1
# 137      1
# 130      1
# 150      1
# 210      1
# 180      1
# 175      1
# 596      1
# 230      1
# Name: count, dtype: int64
# victim_minor
# Y    2788
# N     910
# Name: count, dtype: int64
# block
# (registered as homeless)     535
# 066XX S PERRY AVE             77
# 042XX W CARROLL AVE           42
# 081XX S COTTAGE GROVE AVE     38
# 12XXX S GREEN ST              36
#                             ...
# 050XX  SAN JACINTO ST          1
# 085XX S MACKINAW AVE           1
# 024XX N NEWCASTLE AVE          1
# 021XX N MOBILE AVE             1
# 069XX S PRAIRIE AVE            1
# Name: count, Length: 2202, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# This function constructs a bar plot. It gets called to make several different plots.
# Args; data(series), xlabel(string), ylabel(string), title(string), colorScheme(1; inferno, 2; plasma, 3; magma)
def make_plot(data, xlabel, ylabel, title, colorScheme):
    fig, ax = plt.subplots(figsize = (15, 10))
    
    if (colorScheme == 1):
        colors = plt.cm.inferno(np.linspace(0, 1, 10))

    if (colorScheme == 2):
        colors = plt.cm.plasma(np.linspace(0, 1, 10))
        
    if (colorScheme == 3):
        colors = plt.cm.magma(np.linspace(0, 1, 10))

    data[:10].plot.bar(ax = ax, color = colors)

    plt.xticks(rotation = 45, fontsize = 12)

    plt.tight_layout()

    plt.xlabel(xlabel,fontsize = 20)

    plt.ylabel(ylabel, fontsize = 20)

    plt.title(title, fontsize = 20)

    plt.show()

# %% [markdown]
# First, there will be some plots showing a univariate analysis. The plot below shows the 10 Blocks With The Most Sex Offenders. This is a univariate analysis of the data that investigates the block and it's sex offender count.

# %%
make_plot(data = countBlock, xlabel = "Block", ylabel = "Number of Sex Offenders", title = "10 Blocks With The Most Sex Offenders", colorScheme = 1)

# %%
make_plot(data = countLast, xlabel = "Last Name", ylabel = "Number of Sex Offenders", title = "10 Most Frequent Last Names of Chicago's Sex Offenders", colorScheme = 2)

# %%
make_plot(data = countRace, xlabel = "Race", ylabel = "Sex Offenders", title = "Frequency of Sex Offenders by Race", colorScheme = 3)

# %% [markdown]
# The plot below shows the distribution of gender for sex offenders. This is a univariate analysis that compares gender and sex offender count.

# %%
# Construct a pie plot that shows the sexual offenses by gender.

# Count all the occurrences by gender.
gender_counts = df['gender'].value_counts()

gender_counts.head(10)

gender_counts.plot.pie(autopct='%1.1f%%', startangle=90, labels=gender_counts.index, colors=['#D2B48C','purple'])

plt.ylabel('')

plt.title('Sex Offenders by Gender')
# Out:
# Text(0.5, 1.0, 'Sex Offenders by Gender')

# %%
# Inspect the data schema.
df.columns
# Out:
# Index(['last', 'first', 'block', 'gender', 'race', 'birth_date', 'height',
#        'weight', 'victim_minor'],
#       dtype='object')

# %% [markdown]
# The cell below prepares the data for a plot that shows the ages of all sex offenders. It handles the logic for computing the age of each record. The age and gender boxplot is a multivariate analysis of the data.

# %%
from datetime import datetime

today = datetime.today()

# convert the birth_date to datetime

df['birth_date'] = pd.to_datetime(df['birth_date'])

# handles the logic for calculating the age for each record

age_data = pd.DataFrame(df['birth_date'].apply(lambda row: int(today.year - row.year - ((today.month, today.day) < (row.month, row.day) ))) ) 

age_data = age_data.rename(columns={'birth_date': 'age'})

age_data.columns

age_data.head(10)
# Out:
#       age
# 3083   49
# 780    63
# 2654   31
# 1893   59
# 146    54
# 1380   34
# 3550   24
# 1299   25
# 1239   40
# 1978   56

# %%
# Make a box plot using ages of sex offenders. Add title and labels.
import seaborn as sns

sns.boxplot(data = age_data, x = 'age')

plt.title('Ages of Sex Offenders')

plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
# Make a boxplot using age and gender of sex offenders.
gender_age = pd.concat([age_data, df['gender']], axis = 1)

palette = {'MALE': 'lightblue', 'FEMALE': 'pink'}

sns.boxplot(data = gender_age, x='age', y='gender', palette = palette)

plt.title('Box Plot of Ages by Gender for Sex Offenders')

plt.xlabel('Age')

plt.ylabel('Gender')

plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_12944\669975081.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = gender_age, x='age', y='gender', palette = palette)
# Text(0, 0.5, 'Gender')

# %% [markdown]
# The cell blow will be used to calculate descriptive statistics.
# E.g. Mean, median, mode, variance, standard deviation, and range of ages of sex offenders.
# Note, the median value is the 50% percentile in the dataset.

# %%
#age_data.head(25)

print(age_data['age'].describe())
# Out:
# 49.81016765819362 49.0 0    43
# Name: age, dtype: int64 12.719277535142323
# count    3698.000000
# mean       49.810168
# std        12.719278
# min        20.000000
# 25%        40.000000
# 50%        49.000000
# 75%        59.000000
# max        95.000000
# Name: age, dtype: float64

# %% [markdown]
# The fact that the mean age (49.81 years) and median age (49 years) are close suggests that there is not much skewness in the data and it is reasonably symmetric.
# The age range goes from 20 years to 95 years.
# The standard deviation of 12.72 years suggests a moderate spread around the mean.

# %% [markdown]
# The next task is to use the Chicago Crime Database's API endpoint to get data. It is stored in the names crime_data_2 and crime_data_3.

# %%
import requests
import pandas as pd
# This function returns data from the City of Chicago's API in a DataFrame.
# Args: url(API endpoint), limit(number of records to request), offset(first record begins here)
# return: DataFrame with records. More useful for things than JSON because of Pandas.
def get_data(url, limit, offset):
    url = url + "?$limit=" + str(limit) + "&$offset=" + str(offset)
    
    response = requests.get(url)
    
    return pd.read_json(response.text)

# %%
crime_data_2 = get_data(url = "https://data.cityofchicago.org/resource/x2n5-8w5q.json", limit = 100000, offset = 0)

# Used a limit of 100,000.

print(len(crime_data_2))
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_12944\3201390281.py:11: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_json(response.text)
# 100000

# %%
crime_data_2.head(10)
# Out:
#       case_       date_of_occurrence                      block _iucr  \
# 0  JG545511  2023-12-18T05:15:00.000            015XX W 18TH ST  0610
# 1  JG558740  2023-12-18T05:27:00.000           036XX N BROADWAY  0610
# 2  JG545265  2023-12-18T05:27:00.000       050XX S EAST END AVE  3960
# 3  JG551118  2023-12-18T05:30:00.000  057XX S COTTAGE GROVE AVE  0920
# 4  JG545257  2023-12-18T05:35:00.000        061XX W NEWPORT AVE  1320
# 5  JG558282  2023-12-18T05:38:00.000      017XX N HUMBOLDT BLVD  2820
# 6  JG545994  2023-12-18T05:45:00.000            060XX W 63RD ST  0620
# 7  JG545352  2023-12-18T05:51:00.000            018XX W IOWA ST  0820
# 8  JG545262  2023-12-18T05:59:00.000            007XX E 61ST ST  2820
# 9  JG545294  2023-12-18T06:00:00.000          015XX W WALTON ST  0486
#
#   _primary_decsription   _secondary_description         _location_description  \
# 0             BURGLARY           FORCIBLE ENTRY  COMMERCIAL / BUSINESS OFFICE
# 1             BURGLARY           FORCIBLE ENTRY  COMMERCIAL / BUSINESS OFFICE
# 2         INTIMIDATION             INTIMIDATION                     APARTMENT
# 3  MOTOR VEHICLE THEFT     ATTEMPT - AUTOMOBILE                        STREET
# 4      CRIMINAL DAMAGE               TO VEHICLE                        STREET
# 5        OTHER OFFENSE         TELEPHONE THREAT                     APARTMENT
# 6             BURGLARY           UNLAWFUL ENTRY                     APARTMENT
# 7                THEFT           $500 AND UNDER   RESIDENCE - PORCH / HALLWAY
# 8        OTHER OFFENSE         TELEPHONE THREAT                     APARTMENT
# 9              BATTERY  DOMESTIC BATTERY SIMPLE                     APARTMENT
#
#   arrest domestic  beat  ...  y_coordinate   latitude  longitude  \
# 0      N        N  1233  ...     1891492.0  41.857827 -87.664383
# 1      N        N  1925  ...     1924379.0  41.947978 -87.647652
# 2      N        Y   222  ...     1871757.0  41.803182 -87.585432
# 3      N        N   233  ...     1867223.0  41.790872 -87.606143
# 4      N        N  1633  ...     1922300.0  41.942986 -87.779884
# 5      Y        N  1421  ...     1911425.0  41.912740 -87.701945
# 6      N        N   812  ...     1862138.0  41.777849 -87.772324
# 7      N        N  1212  ...     1906030.0  41.897778 -87.673960
# 8      N        Y   313  ...     1864722.0  41.784020 -87.607962
# 9      N        Y  1213  ...     1906426.0  41.898819 -87.666056
#
#                                             location  \
# 0  {'latitude': '41.857826647', 'longitude': '-87...
# 1  {'latitude': '41.947977584', 'longitude': '-87...
# 2  {'latitude': '41.803181616', 'longitude': '-87...
# 3  {'latitude': '41.790872026', 'longitude': '-87...
# 4  {'latitude': '41.942985916', 'longitude': '-87...
# 5  {'latitude': '41.912740324', 'longitude': '-87...
# 6  {'latitude': '41.777849017', 'longitude': '-87...
# 7  {'latitude': '41.897777894', 'longitude': '-87...
# 8  {'latitude': '41.78402007', 'longitude': '-87....
# 9  {'latitude': '41.898818952', 'longitude': '-87...
#
#    :@computed_region_awaf_s7ux  :@computed_region_6mkv_f3dw  \
# 0                          8.0                      14920.0
# 1                         37.0                      21186.0
# 2                          1.0                      21192.0
# 3                         32.0                      22260.0
# 4                         25.0                      22254.0
# 5                         15.0                      22535.0
# 6                         35.0                      22268.0
# 7                         16.0                      21560.0
# 8                         53.0                      22260.0
# 9                         24.0                      22620.0
#
#   :@computed_region_vrxf_vc4k  :@computed_region_bdys_3d7i  \
# 0                        33.0                        270.0
# 1                        57.0                        726.0
# 2                         5.0                        400.0
# 3                         8.0                        154.0
# 4                        17.0                        459.0
# 5                        24.0                        389.0
# 6                        62.0                        265.0
# 7                        25.0                        462.0
# 8                         9.0                        471.0
# 9                        25.0                        484.0
#
#    :@computed_region_43wa_7qmu  :@computed_region_rpca_8um6
# 0                         26.0                         43.0
# 1                         39.0                         53.0
# 2                         33.0                         10.0
# 3                         33.0                         60.0
# 4                         44.0                         52.0
# 5                         49.0                          1.0
# 6                         15.0                          7.0
# 7                         11.0                          4.0
# 8                          4.0                         60.0
# 9                         41.0                         49.0
#
# [10 rows x 23 columns]

# %% [markdown]
# Note, this dataset shows the date of occurrence.

# %%
url = "https://data.cityofchicago.org/resource/x2n5-8w5q.json"

crime_data_3 = get_data(url, 100000, 100000)

print(len(crime_data_3))
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_12944\3201390281.py:11: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_json(response.text)
# 100000

# %% [markdown]
# import kaggle
#
# kaggle.api.dataset_download_files('doyouevendata/chicago-community-areas-geojson', path = './', unzip = True)
#
# print("successfully downloaded the geojson file that contains a map of Chicago.")

# %% [markdown]
# import matplotlib.pyplot as plt
# import geopandas as gpd
#
# gdf = gpd.read_file('chicago-community-areas.geojson')
#
# fix, ax = plt.subplots()
#
# gdf.plot(ax = ax)
#
# plt.show()

# %% [markdown]
# import requests
# # raw data in GeoJSON format from the map I want.
# url = "https://raw.githubusercontent.com/RandomFractals/ChicagoCrimes/master/data/chicago-community-areas.geojson"
#
# response = requests.get(url)
#
# with open('chicago-areas.geojson', 'w') as file:
#     file.write(response.text)

# %% [markdown]
# import geopandas as gpd
# import matplotlib.pyplot as plt
#
# gdf = gpd.read_file('chicago-areas.geojson')
#
# fix, ax = plt.subplots(figsize=(20,20))
#
# gdf.plot(ax = ax)
#
# plt.show()

# %%
# Prints the columns of the data.
print(crime_data_2.columns)

print(crime_data_2.head(10))
# Out:
# Index(['case_', 'date_of_occurrence', 'block', '_iucr', '_primary_decsription',
#        '_secondary_description', '_location_description', 'arrest', 'domestic',
#        'beat', 'ward', 'fbi_cd', 'x_coordinate', 'y_coordinate', 'latitude',
#        'longitude', 'location', ':@computed_region_awaf_s7ux',
#        ':@computed_region_6mkv_f3dw', ':@computed_region_vrxf_vc4k',
#        ':@computed_region_bdys_3d7i', ':@computed_region_43wa_7qmu',
#        ':@computed_region_rpca_8um6'],
#       dtype='object')
#       case_       date_of_occurrence                      block _iucr  \
# 0  JG545511  2023-12-18T05:15:00.000            015XX W 18TH ST  0610
# 1  JG558740  2023-12-18T05:27:00.000           036XX N BROADWAY  0610
# 2  JG545265  2023-12-18T05:27:00.000       050XX S EAST END AVE  3960
# 3  JG551118  2023-12-18T05:30:00.000  057XX S COTTAGE GROVE AVE  0920
# 4  JG545257  2023-12-18T05:35:00.000        061XX W NEWPORT AVE  1320
# 5  JG558282  2023-12-18T05:38:00.000      017XX N HUMBOLDT BLVD  2820
# 6  JG545994  2023-12-18T05:45:00.000            060XX W 63RD ST  0620
# 7  JG545352  2023-12-18T05:51:00.000            018XX W IOWA ST  0820
# 8  JG545262  2023-12-18T05:59:00.000            007XX E 61ST ST  2820
# 9  JG545294  2023-12-18T06:00:00.000          015XX W WALTON ST  0486
#
#   _primary_decsription   _secondary_description         _location_description  \
# 0             BURGLARY           FORCIBLE ENTRY  COMMERCIAL / BUSINESS OFFICE
# 1             BURGLARY           FORCIBLE ENTRY  COMMERCIAL / BUSINESS OFFICE
# 2         INTIMIDATION             INTIMIDATION                     APARTMENT
# 3  MOTOR VEHICLE THEFT     ATTEMPT - AUTOMOBILE                        STREET
# 4      CRIMINAL DAMAGE               TO VEHICLE                        STREET
# 5        OTHER OFFENSE         TELEPHONE THREAT                     APARTMENT
# 6             BURGLARY           UNLAWFUL ENTRY                     APARTMENT
# 7                THEFT           $500 AND UNDER   RESIDENCE - PORCH / HALLWAY
# 8        OTHER OFFENSE         TELEPHONE THREAT                     APARTMENT
# 9              BATTERY  DOMESTIC BATTERY SIMPLE                     APARTMENT
#
#   arrest domestic  beat  ...  y_coordinate   latitude  longitude  \
# 0      N        N  1233  ...     1891492.0  41.857827 -87.664383
# 1      N        N  1925  ...     1924379.0  41.947978 -87.647652
# 2      N        Y   222  ...     1871757.0  41.803182 -87.585432
# 3      N        N   233  ...     1867223.0  41.790872 -87.606143
# 4      N        N  1633  ...     1922300.0  41.942986 -87.779884
# 5      Y        N  1421  ...     1911425.0  41.912740 -87.701945
# 6      N        N   812  ...     1862138.0  41.777849 -87.772324
# 7      N        N  1212  ...     1906030.0  41.897778 -87.673960
# 8      N        Y   313  ...     1864722.0  41.784020 -87.607962
# 9      N        Y  1213  ...     1906426.0  41.898819 -87.666056
#
#                                             location  \
# 0  {'latitude': '41.857826647', 'longitude': '-87...
# 1  {'latitude': '41.947977584', 'longitude': '-87...
# 2  {'latitude': '41.803181616', 'longitude': '-87...
# 3  {'latitude': '41.790872026', 'longitude': '-87...
# 4  {'latitude': '41.942985916', 'longitude': '-87...
# 5  {'latitude': '41.912740324', 'longitude': '-87...
# 6  {'latitude': '41.777849017', 'longitude': '-87...
# 7  {'latitude': '41.897777894', 'longitude': '-87...
# 8  {'latitude': '41.78402007', 'longitude': '-87....
# 9  {'latitude': '41.898818952', 'longitude': '-87...
#
#    :@computed_region_awaf_s7ux  :@computed_region_6mkv_f3dw  \
# 0                          8.0                      14920.0
# 1                         37.0                      21186.0
# 2                          1.0                      21192.0
# 3                         32.0                      22260.0
# 4                         25.0                      22254.0
# 5                         15.0                      22535.0
# 6                         35.0                      22268.0
# 7                         16.0                      21560.0
# 8                         53.0                      22260.0
# 9                         24.0                      22620.0
#
#   :@computed_region_vrxf_vc4k  :@computed_region_bdys_3d7i  \
# 0                        33.0                        270.0
# 1                        57.0                        726.0
# 2                         5.0                        400.0
# 3                         8.0                        154.0
# 4                        17.0                        459.0
# 5                        24.0                        389.0
# 6                        62.0                        265.0
# 7                        25.0                        462.0
# 8                         9.0                        471.0
# 9                        25.0                        484.0
#
#    :@computed_region_43wa_7qmu  :@computed_region_rpca_8um6
# 0                         26.0                         43.0
# 1                         39.0                         53.0
# 2                         33.0                         10.0
# 3                         33.0                         60.0
# 4                         44.0                         52.0
# 5                         49.0                          1.0
# 6                         15.0                          7.0
# 7                         11.0                          4.0
# 8                          4.0                         60.0
# 9                         41.0                         49.0
#
# [10 rows x 23 columns]

# %% [markdown]
# This is a source code acknowlegement; https://github.com/RandomFractals/ChicagoCrimes/blob/master/notebooks/all-chicago-crime-charts.ipynb
#
# The cell below displays a plot that shows the frequency of crime reports for each of Chicago's wards.

# %%
grouped_by_ward = crime_data_2.groupby('ward')

countWards = grouped_by_ward['ward'].value_counts().sort_values()

countWards.plot(kind = 'barh', figsize = (18, 12), color = '#cc0000')

plt.xlabel('Number Of Crime Reports', fontsize = 20)

plt.ylabel('Ward', fontsize = 20)

start_date = str(crime_data_2.head(1)['date_of_occurrence'])[5:15]

end_date = str(crime_data_2.tail(1)['date_of_occurrence'])[9:19]

plt.title('Crimes by Chicago Ward between ' + start_date + ' - ' + end_date, fontsize = 20)

plt.tight_layout()

plt.xticks(fontsize = 16)

plt.yticks(fontsize = 16)

ax = plt.gca()

#ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

plt.show()

# %% [markdown]
# This cell below transforms the data in order to show the total number of crimes committed by crime type. The column called _primary_decscription denotes the crime type.

# %%
# %%time

crime_types = crime_data_2[['_primary_decsription']] # return a DF

crime_type_totals = pd.DataFrame(crime_types.groupby('_primary_decsription').size() )

crime_type_totals.rename(columns = {0 : 'total'}, inplace=True)
# Out:
# CPU times: total: 46.9 ms
# Wall time: 37.8 ms

# %% [markdown]
# The cell below shows a bar plot with the crimes types in Chicago.

# %%
crime_type_totals.head(10)

# Ensure 'total' column is numeric

crime_type_totals['total'] = pd.to_numeric(crime_type_totals['total'], errors='coerce')

# Sort values by number of crimes per each crime type.

crime_type_totals.sort_values(by='total', ascending=True, inplace=True)

# %%
# Select a plot to use to display the total number of occurrences for each crime type.
crime_type_totals.plot(kind = 'barh', figsize = (18, 18), color = '#cc0000')

plt.title("Number of Crimes for Each Crime Type")

plt.xlabel("Number")

plt.ylabel("Crime Type")
# Out:
# Text(0, 0.5, 'Crime Type')

# %%
crime_type_totals.head(10)
# Out:
#                                    total
# _primary_decsription
# ARSON                                199
# ASSAULT                             9105
# BATTERY                            17706
# BURGLARY                            2918
# CONCEALED CARRY LICENSE VIOLATION     60
# CRIMINAL DAMAGE                    11217
# CRIMINAL SEXUAL ASSAULT              577
# CRIMINAL TRESPASS                   1888
# DECEPTIVE PRACTICE                  6482
# GAMBLING                               6

# %%
# Make a pie plot of the data to show what types of crimes are most prevalent.
plt.figure(figsize=(12,8))

plt.pie(crime_type_totals['total'], autopct='%1.1f%%', startangle=90)

# Add legend outside the pie chart
plt.legend(
    labels=crime_type_totals.index,  # Labels corresponding to crime types
    title="Crime Types",  # Title for the legend
    bbox_to_anchor=(1.1, 1),  # Position legend outside the chart
    loc='upper left',  # Location of the legend
    fontsize=10  # Adjust font size for readability
)

plt.title("Crimes in Chicago")

plt.tight_layout()

plt.show()
